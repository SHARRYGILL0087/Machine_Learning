# %% [markdown]
# # REGRESSION ANALYSIS

# %% [markdown]
# # -> Linear Regression Algorithm (Simple Linear)

# %% [markdown]
# # Simple Linear Regression - y = mx + c

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv(r"C:\Users\SHAMSHER\Downloads\placement_dataset_100.csv")
dataset.head(3)
# Out:
#    cgpa  package
# 0  8.07     3.08
# 1  6.32     1.94
# 2  8.54     4.01

# %%
plt.Figure(figsize=(5,3))
sns.scatterplot(x='cgpa' , y='package' , data=dataset)
plt.show()

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x = dataset[['cgpa']]
y = dataset[['package']]
# x.ndim # should be 2 dimension data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# To check the predict is good or not -> we hv to find the (accuracy score)

# %%
lr.score(x_test,y_test) # This give the Accuracy
# Out:
# 0.9648825977453425

# %% [markdown]
# 8.07-	3.08 ,	6.32-	1.94

# %%
lr.predict([[6.32]])
# Out:
# C:\Users\SHAMSHER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.21730419]])

# %%
#  y= mx + c

# %%
lr.coef_ # Give Coffecient of x (m)
# Out:
# array([[0.7299886]])

# %%
lr.intercept_ # Give Intercept (c)
# Out:
# array([-2.39622378])

# %%
# y = 0.7299886*x + -2.39622378 This is the Equation formed of the data

# %%
y_prd = lr.predict(x)

# %%
plt.Figure(figsize=(5,3))
sns.scatterplot(x='cgpa' , y='package' , data=dataset)
plt.plot(dataset['cgpa'],y_prd,c="red")
plt.legend(["org","predict_line"])
plt.savefig("predict.jpg")
plt.show()

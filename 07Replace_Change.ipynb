# %% [markdown]
# # REPLACE AND CHANGE DATA TYPE

# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\SHAMSHER\Downloads\student-lifestyle-and-stress-dataset.csv")
dataset.head(3)
# Out:
#   Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0       school     6.868702     1.711722            3.176942         NaN
# 1       school     8.519088     3.251084            3.880787   93.978465
# 2      college     4.498770     6.306885            2.936172   64.421253
#
#    Exam_Pressure Family_Support  Month  Stress_Level
# 0            8.0              7    2.0             1
# 1            6.0              4    3.0             1
# 2            7.0              1   12.0             1

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25500 entries, 0 to 25499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_Type        24248 non-null  object
#  1   Sleep_Hours         24167 non-null  float64
#  2   Study_Hours         24223 non-null  float64
#  3   Social_Media_Hours  24188 non-null  float64
#  4   Attendance          24195 non-null  float64
#  5   Exam_Pressure       24230 non-null  float64
#  6   Family_Support      25500 non-null  float64
#  7   Month               24186 non-null  float64
#  8   Stress_Level        25500 non-null  int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.8+ MB

# %%
dataset.isnull().sum()
# Out:
# Student_Type          1252
# Sleep_Hours           1333
# Study_Hours           1277
# Social_Media_Hours    1312
# Attendance            1305
# Exam_Pressure         1270
# Family_Support           0
# Month                 1314
# Stress_Level             0
# dtype: int64

# %%
dataset['Family_Support'].value_counts()
# Out:
# Family_Support
# 6     5618
# 7     3915
# 5     3816
# 8     2732
# 4     2433
# 9     1937
# 3     1902
# 2     1239
# 10     978
# 1      928
# 8        2
# Name: count, dtype: int64

# %%
dataset['Family_Support'].fillna(dataset['Family_Support'].mode()[0],inplace=True)
# Out:
# C:\Users\SHAMSHER\AppData\Local\Temp\ipykernel_27260\4039419057.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Family_Support'].fillna(dataset['Family_Support'].mode()[0],inplace=True)

# %%
dataset['Family_Support'].replace(skds,8,inplace=True)

# %%
dataset['Family_Support'].replace(1232,8,inplace=True)

# %%
dataset['Family_Support'] = dataset['Family_Support'].astype('float64')

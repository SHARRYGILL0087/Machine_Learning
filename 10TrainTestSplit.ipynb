# %% [markdown]
# # TRAIN TEST SPLIT IN DATASET

# %% [markdown]
# In Supervise ML

# %% [markdown]
# Dependent and Independent Variables

# %% [markdown]
# Input and Output

# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\SHAMSHER\Downloads\Sport car price.csv")
dataset.head(3)
# Out:
#       Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0      Porsche       911  2022               3        379            331
# 1  Lamborghini   Huracan  2021             5.2        630            443
# 2      Ferrari   488 GTB  2022             3.9        661            561
#
#   0-60 MPH Time (seconds) Price (in USD)
# 0                       4        101,200
# 1                     2.8        274,390
# 2                       3        333,750

# %%
input_data = dataset.iloc[:,:-1]
# input_data
output_data = dataset['Price (in USD)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(input_data,output_data,test_size=0.23)

# %%
dataset.shape , x_train.shape , y_train.shape , x_test.shape , y_test.shape
# Out:
# ((1007, 8), (775, 7), (775,), (232, 7), (232,))
